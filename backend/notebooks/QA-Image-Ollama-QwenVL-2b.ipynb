\xd3@\xd1#\x8c\x91\xe9\\\xa5\xd7\x8e\xb5\r6\xf5m"\x7f\x9b\x19 \x9f\xbd\xed]&\x9b\xae[\xeb6kq\x01\xe4\x7f\xac_CA\x99\xe1_\x1c\xbc/}i}$\xccr\xae8\xf9q\x8a\xf2{\xa5x\t%s\xcf"\xbe\xa2\xf8\xb1\xe1\xc8\xf5\x8d\x15\xdcB\x0b\xa8\'5\xf3\xbf\x89\xf4u\xb3\x99\xb0\x84\x0c\xf3@\x1d/\xec\xc5\xf1-\xbe\x1c|T\xd3\xb5\xb31H^P\x93c\xdf \x1f\xd6\xbfc\xa2\xf8\x81a\xe3\xff\x00\xd9o\xfbF=@3\xd9A\xfb\xf2{\x8c\x82\x0f\x15\xf8g\x04om8\x96&+\xe9\x83_\xa0\xbf\xb2\xf7\xedki\x1f\xec\xe37\x82\xf5\x8dP\x9b\x8f! ...

# %%
model_id = 'qwen3-vl:2b'
client.chat(model=model_id, messages=messages, stream=False)

# HOW THE FUCK CAN I RUN THIS LOCALLY??
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[5], line 2
#       1 model_id = 'qwen3-vl:2b'
# ----> 2 client.chat(model=model_id, messages=messages, stream=False)
#
# File ~/.cache/pypoetry/virtualenvs/clear-vision-backend-pHRXtyny-py3.12/lib/python3.12/site-packages/ollama/_client.py:365, in Client.chat(self, model, messages, tools, stream, think, logprobs, top_logprobs, format, options, keep_alive)
#     318 def chat(
#     319   self,
#     320   model: str = '',
#    (...)    330   keep_alive: Optional[Union[float, str]] = None,
#     331 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     332   """
#     333   Create a chat response using the requested model.
#     334
#    (...)    363   Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     364   """
# --> 365   return self._request(
#     366     ChatResponse,
#     367     'POST',
#     368     '/api/chat',
#     369     json=ChatRequest(
#     370       model=model,
#     371       messages=list(_copy_messages(messages)),
#     372       tools=list(_copy_tools(tools)),
#     373       stream=stream,
#     374       think=think,
#     375       logprobs=logprobs,
#     376       top_logprobs=top_logprobs,
#     377       format=format,
#     378       options=options,
#     379       keep_alive=keep_alive,
#     380     ).model_dump(exclude_none=True),
#     381     stream=stream,
#     382   )
#
# File ~/.cache/pypoetry/virtualenvs/clear-vision-backend-pHRXtyny-py3.12/lib/python3.12/site-packages/ollama/_client.py:189, in Client._request(self, cls, stream, *args, **kwargs)
#     185         yield cls(**part)
#     187   return inner()
# --> 189 return cls(**self._request_raw(*args, **kwargs).json())
#
# File ~/.cache/pypoetry/virtualenvs/clear-vision-backend-pHRXtyny-py3.12/lib/python3.12/site-packages/ollama/_client.py:133, in Client._request_raw(self, *args, **kwargs)
#     131   return r
#     132 except httpx.HTTPStatusError as e:
# --> 133   raise ResponseError(e.response.text, e.response.status_code) from None
#     134 except httpx.ConnectError:
#     135   raise ConnectionError(CONNECTION_ERROR_MESSAGE) from None
#
# ResponseError: model requires more system memory (6.6 GiB) than is available (2.6 GiB) (status code: 500)
