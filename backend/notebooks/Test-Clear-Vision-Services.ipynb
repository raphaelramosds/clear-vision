# %%
import os
import sys
sys.path.append(os.path.abspath(".."))

# %%
from clear_vision.adapters.detectors import LlavaTargetDetector
from clear_vision.adapters.frame_samplers import Cv2FullVideoFrameSampler
from clear_vision.domain.services import InferenceService


inference_service = InferenceService(
    detector=LlavaTargetDetector(), frame_sampler=Cv2FullVideoFrameSampler()
)

# %%
video_path = os.path.abspath("../public/video_rua01.mp4")

inference_result = inference_service.run_video_target_detection(
    video_path=video_path,
    target="black car"
)

inference_result.model_dump()
# Out:
# {'uid': UUID('50293c34-c2ed-464a-9e94-9ad9b6d6d669'),
#  'target': 'black car',
#  'detections': [{'ts': 0.0,
#    'target_exists': True,
#    'description': 'A car driving down a street.'},
#   {'ts': 1.0,
#    'target_exists': True,
#    'description': 'A black car is visible in the image.'},
#   {'ts': 4.0,
#    'target_exists': True,
#    'description': 'A black car is visible in the image.'},
#   {'ts': 6.0,
#    'target_exists': True,
#    'description': 'A black car is visible in the image.'},
#   {'ts': 13.0,
#    'target_exists': True,
#    'description': 'A black car is present in the image.'}]}
